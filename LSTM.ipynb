# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score

# Load data
df = pd.read_csv('Final Transactions.csv')

# Drop non-numeric and unnecessary columns
df = df.drop(columns=['TRANSACTION_ID', 'TX_DATETIME', 'CUSTOMER_ID', 'TERMINAL_ID', 'TX_FRAUD_SCENARIO'])

# Handle missing values (if any)
df.fillna(df.median(), inplace=True)

# Extract features (X) and target variable (y)
X = df.drop(columns=['TX_FRAUD'])
y = df['TX_FRAUD']

# Standardize the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Reshape data for LSTM (LSTM requires 3D input: samples, time steps, features)
X_reshaped = X_scaled.reshape(X_scaled.shape[0], 1, X_scaled.shape[1])

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_reshaped, y, test_size=0.3, random_state=42)

# Build LSTM model
model = Sequential([
    LSTM(64, return_sequences=True, input_shape=(1, X.shape[1])),
    Dropout(0.2),
    LSTM(32, return_sequences=False),
    Dropout(0.2),
    Dense(1, activation='sigmoid')
])

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(X_train, y_train, epochs=20, batch_size=32, validation_data=(X_test, y_test))

# Predictions
y_pred_prob = model.predict(X_test)
y_pred = (y_pred_prob > 0.5).astype(int).flatten()

# Calculate accuracy and precision
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)

print("LSTM Training Accuracy:", model.evaluate(X_train, y_train)[1])
print("LSTM Testing Accuracy:", accuracy)
print("LSTM Precision:", precision)
# Out:
# C:\Users\lenovo\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:205: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/20
# 38373/38373 ━━━━━━━━━━━━━━━━━━━━ 264s 7ms/step - accuracy: 0.9864 - loss: 0.0575 - val_accuracy: 0.9936 - val_loss: 0.0325
# Epoch 2/20
# 38373/38373 ━━━━━━━━━━━━━━━━━━━━ 270s 7ms/step - accuracy: 0.9931 - loss: 0.0348 - val_accuracy: 0.9931 - val_loss: 0.0332
# Epoch 3/20
# 38373/38373 ━━━━━━━━━━━━━━━━━━━━ 245s 6ms/step - accuracy: 0.9933 - loss: 0.0342 - val_accuracy: 0.9917 - val_loss: 0.0375
# Epoch 4/20
# 38373/38373 ━━━━━━━━━━━━━━━━━━━━ 270s 7ms/step - accuracy: 0.9934 - loss: 0.0338 - val_accuracy: 0.9935 - val_loss: 0.0326
# Epoch 5/20
# 38373/38373 ━━━━━━━━━━━━━━━━━━━━ 278s 7ms/step - accuracy: 0.9935 - loss: 0.0339 - val_accuracy: 0.9936 - val_loss: 0.0324
# Epoch 6/20
# 38373/38373 ━━━━━━━━━━━━━━━━━━━━ 247s 6ms/step - accuracy: 0.9938 - loss: 0.0329 - val_accuracy: 0.9946 - val_loss: 0.0309
# Epoch 7/20
# 38373/38373 ━━━━━━━━━━━━━━━━━━━━ 283s 7ms/step - accuracy: 0.9937 - loss: 0.0329 - val_accuracy: 0.9949 - val_loss: 0.0305
# Epoch 8/20
# 38373/38373 ━━━━━━━━━━━━━━━━━━━━ 238s 6ms/step - accuracy: 0.9938 - loss: 0.0330 - val_accuracy: 0.9944 - val_loss: 0.0308
# Epoch 9/20
# 38373/38373 ━━━━━━━━━━━━━━━━━━━━ 306s 7ms/step - accuracy: 0.9939 - loss: 0.0324 - val_accuracy: 0.9937 - val_loss: 0.0317
# Epoch 10/20
# 38373/38373 ━━━━━━━━━━━━━━━━━━━━ 273s 7ms/step - accuracy: 0.9937 - loss: 0.0329 - val_accuracy: 0.9944 - val_loss: 0.0306
# Epoch 11/20
# 38373/38373 ━━━━━━━━━━━━━━━━━━━━ 324s 7ms/step - accuracy: 0.9939 - loss: 0.0324 - val_accuracy: 0.9947 - val_loss: 0.0305
# Epoch 12/20
# 38373/38373 ━━━━━━━━━━━━━━━━━━━━ 248s 5ms/step - accuracy: 0.9939 - loss: 0.0326 - val_accuracy: 0.9933 - val_loss: 0.0327
# Epoch 13/20
# 38373/38373 ━━━━━━━━━━━━━━━━━━━━ 157s 4ms/step - accuracy: 0.9941 - loss: 0.0318 - val_accuracy: 0.9947 - val_loss: 0.0303
# Epoch 14/20
# 38373/38373 ━━━━━━━━━━━━━━━━━━━━ 172s 4ms/step - accuracy: 0.9940 - loss: 0.0323 - val_accuracy: 0.9950 - val_loss: 0.0304
# Epoch 15/20
# 38373/38373 ━━━━━━━━━━━━━━━━━━━━ 163s 4ms/step - accuracy: 0.9940 - loss: 0.0324 - val_accuracy: 0.9931 - val_loss: 0.0333
# Epoch 16/20
# 38373/38373 ━━━━━━━━━━━━━━━━━━━━ 139s 4ms/step - accuracy: 0.9941 - loss: 0.0319 - val_accuracy: 0.9939 - val_loss: 0.0316
# Epoch 17/20
# 38373/38373 ━━━━━━━━━━━━━━━━━━━━ 144s 4ms/step - accuracy: 0.9941 - loss: 0.0321 - val_accuracy: 0.9939 - val_loss: 0.0314
# Epoch 18/20
# 38373/38373 ━━━━━━━━━━━━━━━━━━━━ 136s 4ms/step - accuracy: 0.9941 - loss: 0.0322 - val_accuracy: 0.9944 - val_loss: 0.0308
# Epoch 19/20
# 38373/38373 ━━━━━━━━━━━━━━━━━━━━ 138s 4ms/step - accuracy: 0.9940 - loss: 0.0325 - val_accuracy: 0.9929 - val_loss: 0.0338
# Epoch 20/20
# 38373/38373 ━━━━━━━━━━━━━━━━━━━━ 135s 4ms/step - accuracy: 0.9942 - loss: 0.0317 - val_accuracy: 0.9934 - val_loss: 0.0327
# 16446/16446 ━━━━━━━━━━━━━━━━━━━━ 28s 2ms/step
# 38373/38373 ━━━━━━━━━━━━━━━━━━━━ 65s 2ms/step - accuracy: 0.9934 - loss: 0.0329
# LSTM Training Accuracy: 0.993416428565979
# LSTM Testing Accuracy: 0.9933529312281115
# LSTM Precision: 0.9942605114424664
